# %%
# -------------------------------------------
# 1. Import required libraries
# -------------------------------------------
import pandas as pd
from statsmodels.stats.weightstats import ztest

# -------------------------------------------
# 2. Load your patient dataset
# -------------------------------------------
df = pd.read_csv("patients.csv")   # make sure the file is in the same folder

# Display first few rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 5
#       1 # -------------------------------------------
#       2 # 1. Import required libraries
#       3 # -------------------------------------------
#       4 import pandas as pd
# ----> 5 from statsmodels.stats.weightstats import ztest
#       7 # -------------------------------------------
#       8 # 2. Load your patient dataset
#       9 # -------------------------------------------
#      10 df = pd.read_csv("patients.csv")   # make sure the file is in the same folder
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
# -------------------------------------------
# 3. One-sample Z-test
# -------------------------------------------
column = "BloodPressure"   # change this to your column name

z_stat, p_value = ztest(df[column].dropna(), value=120)

print("Z-statistic:", z_stat)
print("P-value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       1 # -------------------------------------------
#       2 # 3. One-sample Z-test
#       3 # -------------------------------------------
#       4 column = "BloodPressure"   # change this to your column name
# ----> 6 z_stat, p_value = ztest(df[column].dropna(), value=120)
#       8 print("Z-statistic:", z_stat)
#       9 print("P-value:", p_value)
#
# NameError: name 'ztest' is not defined

# %%
# -------------------------------------------
# 4. Two-sample Z-test (Male vs Female)
# -------------------------------------------
column = "BloodPressure"   # numeric variable
group_col = "Gender"       # grouping column

group1 = df[df[group_col] == "Male"][column].dropna()
group2 = df[df[group_col] == "Female"][column].dropna()

z_stat, p_value = ztest(group1, group2)

print("Z-statistic:", z_stat)
print("P-value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 7
#       4 column = "BloodPressure"   # numeric variable
#       5 group_col = "Gender"       # grouping column
# ----> 7 group1 = df[df[group_col] == "Male"][column].dropna()
#       8 group2 = df[df[group_col] == "Female"][column].dropna()
#      10 z_stat, p_value = ztest(group1, group2)
#
# NameError: name 'df' is not defined

# %%
# -------------------------------------------
# 5. Z-test for proportions
# -------------------------------------------
import statsmodels.api as sm

# count of recovered patients
successes = df["Recovered"].value_counts()["Yes"]

# total number of patients
n = len(df)

# hypothesized population proportion (example: 0.8)
p0 = 0.8

z_stat, p_value = sm.stats.proportions_ztest(successes, n, p0)

print("Z-statistic:", z_stat)
print("P-value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       1 # -------------------------------------------
#       2 # 5. Z-test for proportions
#       3 # -------------------------------------------
# ----> 4 import statsmodels.api as sm
#       6 # count of recovered patients
#       7 successes = df["Recovered"].value_counts()["Yes"]
#
# ModuleNotFoundError: No module named 'statsmodels'
